# %%
import numpy as np
import os
from Bio import SeqIO #pip install biopython
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

# %%
#step 1
def generate_motif(ML, ICPC): 
    if ICPC == 2:
        results = []
        for i in range(ML):
            col = [0,0,0,0]
            loc = np.random.randint(0,4)
            col[loc] = 1
            results.append(col)
        return results
    
    
    eplison = 0.01
    
    def n_sum(ICs, ML, ICPC):
        if ML == 6:
            for a in range(0, len(ICs) - 5):
                for b in range(1, len(ICs) - 4):
                    for c in range(2, len(ICs) - 3):
                        for d in range(3, len(ICs) - 2):
                            for e in range(4, len(ICs) - 1):
                                for f in range(5, len(ICs)):
                                    if abs(ICs[a] + ICs[b] + ICs[c] + ICs[d] + ICs[e] + ICs[f] - ICPC * 6) <  eplison and len(set([a,b,c,d,e,f])) == 6:
                                        return [a,b,c,d,e,f]
        elif ML == 7:
            for a in range(0, len(ICs) - 6):
                for b in range(1, len(ICs) - 5):
                    for c in range(2, len(ICs) - 4):
                        for d in range(3, len(ICs) - 3):
                            for e in range(4, len(ICs) - 2):
                                for f in range(5, len(ICs) - 1):
                                    for g in range(5, len(ICs)):
                                        if abs(ICs[a] + ICs[b] + ICs[c] + ICs[d] + ICs[e] + ICs[f] + ICs[g] - ICPC * 7) <  eplison and len(set([a,b,c,d,e,f,g])) == 7:
                                            return [a,b,c,d,e,f,g]
        else: #8
            for a in range(0, len(ICs) - 7):
                for b in range(1, len(ICs) - 6):
                    for c in range(2, len(ICs) - 5):
                        for d in range(3, len(ICs) - 4):
                            for e in range(4, len(ICs) - 3):
                                for f in range(5, len(ICs) - 2):
                                    for g in range(5, len(ICs) - 1):
                                        for h in range(6, len(ICs)):
                                            if abs(ICs[a] + ICs[b] + ICs[c] + ICs[d] + ICs[e] + ICs[f] + ICs[g] + ICs[h] - ICPC * 8) <  eplison and len(set([a,b,c,d,e,f,g,h])) == 8:
                                                return [a,b,c,d,e,f,g,h]
        return []
    
    def calc_IC(col):
        return sum([col[i]*np.log2(4 * col[i]) for i in range(4)])
    
    
    idxs = []
    while len(idxs) == 0:
        cols = []
        ICs = []
        while len(ICs) < ML * 2:
            rvs = sorted(np.random.uniform(size = 3))
            col = [rvs[0] - 0, rvs[1] - rvs[0], rvs[2] - rvs[1], 1 - rvs[2]]
            IC = calc_IC(col)
            if IC >= ICPC - 0.1:
                ICs.append(IC)
                cols.append(col)
        idxs = n_sum(ICs, ML, ICPC)
    
    results = []
    for idx in idxs:
        results.append(cols[idx])
        
    return results
    
    
def build_benchmark(ICPC, ML, SL, SC, index):
    ACGT = ['A', 'C', 'G', 'T']
    #2)
    sequences = []
    for i in range(SC):
        sequence = []
        for j in range(SL):
            k = np.random.randint(0,4)
            sequence.append(ACGT[k])
        sequences.append(sequence)
    #3)
    motif = generate_motif(ML, ICPC)
    #4)
    sites = []
    for i in range(SC):
        site = []
        for j in range(ML):
            if ICPC == 2:
                if motif[j][0] == 1:
                    site.append(ACGT[0])
                elif motif[j][1] == 1:
                    site.append(ACGT[1])
                elif motif[j][2] == 1:
                    site.append(ACGT[2])
                else:
                    site.append(ACGT[3])
            else:
                k = np.random.uniform()
                if k < motif[j][0]:
                    site.append(ACGT[0])
                elif k >= motif[j][0] and k < motif[j][0] + motif[j][1]:
                    site.append(ACGT[1])
                elif k >= motif[j][0] + motif[j][1] and k < motif[j][0] + motif[j][1] + motif[j][2]:
                    site.append(ACGT[2])
                else:
                    site.append(ACGT[3])
        sites.append(site)
    #5)
    sites_location = []
    for i in range(SC):
        j = np.random.randint(0,SC) #check idx
        k = np.random.randint(0,SL - ML) #check idx
        sequences[i][k: k + ML] = sites[j] #check idx
        sites_location.append(k)
    #6)
    location = 'data_set_' + str(index)
    if not os.path.exists(location):
        os.makedirs(location)
    
    s = []   
    for i in sequences:
        s.append(SeqRecord(Seq(''.join(i))))
    
    SeqIO.write(s, os.path.join(location, 'sequences' + ".fasta"), "fasta")
    
    #7)
    f = open(os.path.join(location, 'sites' + ".txt"), 'w+')
    for i in sites_location:
        f.write(str(i))
        f.write(',')
    f.close()
    #8)
    f = open(os.path.join(location, 'motif' + ".txt"), 'w+')
    f.write('MOTIF' + str(index) + ' ' + str(ML))
    f.write('\n')
    for i in motif:
        for j in i:
            f.write(str(j))
            f.write(',')
        f.write('\n')
    f.close()
    #9)
    with open(os.path.join(location, 'motiflength' + ".txt"), 'w+') as f:
        f.write(str(ML))
        #f.close()

# %%
for i in range(10):
    build_benchmark(1,7,500,10,0 + i)

# %%
for i in range(10):
    build_benchmark(1.5,7,500,10,10 + i)

# %%
for i in range(10):
    build_benchmark(2,7,500,10,20 + i)
for i in range(10):
    build_benchmark(1.5,6,500,10,30 + i)

# %%
for i in range(10):
    build_benchmark(1.5,8,500,10,40 + i)

# %%
for i in range(10):
    build_benchmark(1.5,7,500,5,50 + i)

# %%
for i in range(10):
    build_benchmark(1.5,7,500,20,60 + i)

# %%
#step 2
def motif_finder(index):
    def kernel(x):
        #return 1 
        #return x 
        #return x**2 
        return x**2/2
        #return x**(x/2)
        #return x**x 
        
    location = 'data_set_' + str(index) + '/' 
    seqs = []
    for record in SeqIO.parse(os.path.join(location, 'sequences' + ".fasta"), "fasta"):
        seqs.append(str(record.seq))

    with open(os.path.join(location,'motiflength.txt'), 'r') as f:
        ML = int(f.read())
        #f.close()    
    
    
    #find frq-ML pattern
    candidates = {}
    for seq in seqs:
        visited = {}
        for i in range(0,len(seq) - ML):
            if seq[i:i + ML] not in candidates:
                candidates[seq[i:i + ML]] = 1
                visited[seq[i:i + ML]] = 1
            else:
                if seq[i:i + ML] not in visited:
                    visited[seq[i:i + ML]] = 1
                    candidates[seq[i:i + ML]] += 1
                
    sorted_candidates = sorted(candidates.items(), key=lambda x: -x[1])            
    
    #print(sorted_candidates)
    
    min_sup = max(candidates.values()) - 3
    
    #print(min_sup)
    
    frq_ml = [[list(i[0]), i[1]] for i in sorted_candidates if i[1] >= min_sup] #item, weight
    
    #print(frq_ml)
    
    motif = []
    for i in range(ML):
        cols = {}
        sum_ = 0
        for item in frq_ml:
            sum_ += kernel(item[1])
            if item[0][i] not in cols:
                cols[item[0][i]] = kernel(item[1])
            else:
                cols[item[0][i]] += kernel(item[1])
                
        motif.append([
            cols['A']/sum_ if 'A' in cols else 0, 
            cols['C']/sum_ if 'C' in cols else 0, 
            cols['G']/sum_ if 'G' in cols else 0, 
            cols['T']/sum_ if 'T' in cols else 0])
    
    #print(motif)
    
    #sample for motif to find sites
    ACGT = ['A', 'C', 'G', 'T']
    sites = [{} for i in range(len(seqs))]
    N = 10000
    
    for i in range(N):
        site = []
        for j in range(ML):
            if max(motif[j]) - min(motif[j]) >= 0.99999:
                if motif[j][0] == 1:
                    site.append(ACGT[0])
                elif motif[j][1] == 1:
                    site.append(ACGT[1])
                elif motif[j][2] == 1:
                    site.append(ACGT[2])
                else:
                    site.append(ACGT[3])
            else:
                k = np.random.uniform()
                if k < motif[j][0]:
                    site.append(ACGT[0])
                elif k >= motif[j][0] and k < motif[j][0] + motif[j][1]:
                    site.append(ACGT[1])
                elif k >= motif[j][0] + motif[j][1] and k < motif[j][0] + motif[j][1] + motif[j][2]:
                    site.append(ACGT[2])
                else:
                    site.append(ACGT[3])
        
        for idx, seq in enumerate(seqs):
            for j in range(0,len(seq) - ML):
                if ''.join(site) == seq[j:j+ML]:
                    if j not in sites[idx]:
                        sites[idx][j] = 1
                    else:
                        sites[idx][j] += 1
    #print(sites)
    
    sorted_sites = [sorted(sites[i].items(), key=lambda x: -x[1]) for i in range(len(seqs))]
    
    #print([sorted_sites[i][0] for i in range(len(seqs))])

    sites_location = [sorted_sites[i][0][0] for i in range(len(seqs))]
    #print(sites_location)
    
    location = 'data_set_' + str(index)
    f = open(os.path.join(location, 'predicted_motif' + ".txt"), 'w+')
    f.write('MOTIF' + str(index) + ' ' + str(ML))
    f.write('\n')
    for i in motif:
        for j in i:
            f.write(str(j))
            f.write(',')
        f.write('\n')
    f.close()
    
    f = open(os.path.join(location, 'predicted_sites' + ".txt"), 'w+')
    for i in sites_location:
        f.write(str(i))
        f.write(',')
    f.close()

# %%
#step 3
def evaluation(index, start, end):
    location = 'data_set_' + str(index) + '/' 
    with open(os.path.join(location,'motif.txt'), 'r') as f:
        x = f.read().strip().split('\n')
        y = [i.strip().split(',')[:-1] for i in x][1:]
        motif = [[float(j) for j in i] for i in y]
    with open(os.path.join(location,'predicted_motif.txt'), 'r') as f:
        x = f.read().strip().split('\n')
        y = [i.strip().split(',')[:-1] for i in x][1:]
        predicted_motif = [[float(j) for j in i] for i in y]
    with open(os.path.join(location,'sites.txt'), 'r') as f:
        sites = [int(i) for i in f.read().strip().split(',')[:-1]]
    with open(os.path.join(location,'predicted_sites.txt'), 'r') as f:
        predicted_sites = [int(i) for i in f.read().strip().split(',')[:-1]]
    #1)
    def KL(a, b):
        a = np.asarray(a, dtype=np.float)
        b = np.asarray(b, dtype=np.float)
        return np.sum(np.where(a != 0, a * np.log(a / b), 0))

    a = sum([KL(motif[i], predicted_motif[i]) for i in range(len(motif))])
    #2)
    b = sum([1 for i in range(len(sites)) if sites[i] == predicted_sites[i]])
    #3)
    c = sum([1 for i in range(len(sites)) if abs(sites[i] - predicted_sites[i]) < len(motif)/2])
    #4)
    d = end - start
    
    return a, b, c, d

# %%
import time

results = []
for i in range(70):
    start = time.time()
    motif_finder(i)
    end = time.time()
    results.append(evaluation(i, start, end))
# Out:
# C:\Users\ericp\anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in true_divide

# %%
for i, r in enumerate(results):
    print("index: %s, kl: %s, overlap pos: %s, overlap site: %s, time: %s sec" 
          %(str(i),str(np.round(r[0], 3)),str(np.round(r[1], 3)),str(np.round(r[2], 3)),str(np.round(r[3], 3))))
# Out:
# index: 0, kl: 0.689, overlap pos: 0, overlap site: 0, time: 11.497 sec
# index: 1, kl: 0.634, overlap pos: 0, overlap site: 0, time: 11.076 sec
# index: 2, kl: 0.714, overlap pos: 0, overlap site: 0, time: 11.156 sec
# index: 3, kl: 0.698, overlap pos: 0, overlap site: 0, time: 11.2 sec
# index: 4, kl: 0.692, overlap pos: 0, overlap site: 1, time: 11.16 sec
# index: 5, kl: 0.674, overlap pos: 0, overlap site: 0, time: 11.271 sec
# index: 6, kl: 0.723, overlap pos: 0, overlap site: 0, time: 11.265 sec
# index: 7, kl: 0.724, overlap pos: 0, overlap site: 0, time: 11.222 sec
# index: 8, kl: 0.677, overlap pos: 0, overlap site: 0, time: 11.235 sec
# index: 9, kl: 0.67, overlap pos: 0, overlap site: 0, time: 11.183 sec
# index: 10, kl: 1.048, overlap pos: 0, overlap site: 0, time: 11.212 sec
# index: 11, kl: 0.937, overlap pos: 0, overlap site: 0, time: 11.264 sec
# index: 12, kl: 1.012, overlap pos: 0, overlap site: 0, time: 11.18 sec
# index: 13, kl: 1.062, overlap pos: 0, overlap site: 0, time: 11.253 sec
# index: 14, kl: 1.038, overlap pos: 0, overlap site: 0, time: 11.264 sec
# index: 15, kl: 1.026, overlap pos: 1, overlap site: 1, time: 11.287 sec
# index: 16, kl: 1.086, overlap pos: 0, overlap site: 0, time: 11.171 sec
# index: 17, kl: 1.065, overlap pos: 0, overlap site: 0, time: 11.236 sec
# index: 18, kl: 1.056, overlap pos: 0, overlap site: 0, time: 11.223 sec
# index: 19, kl: 1.065, overlap pos: 0, overlap site: 0, time: 11.287 sec
# index: 20, kl: 0.0, overlap pos: 10, overlap site: 10, time: 10.996 sec
# index: 21, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.099 sec
# index: 22, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.08 sec
# index: 23, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.113 sec
# index: 24, kl: 0.0, overlap pos: 9, overlap site: 9, time: 11.105 sec
# index: 25, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.082 sec
# index: 26, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.115 sec
# index: 27, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.057 sec
# index: 28, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.083 sec
# index: 29, kl: 0.0, overlap pos: 10, overlap site: 10, time: 11.115 sec
# index: 30, kl: 1.111, overlap pos: 0, overlap site: 0, time: 10.838 sec
# index: 31, kl: 1.124, overlap pos: 0, overlap site: 0, time: 10.803 sec
# index: 32, kl: 1.061, overlap pos: 0, overlap site: 1, time: 10.806 sec
# index: 33, kl: 1.018, overlap pos: 0, overlap site: 0, time: 10.905 sec
# index: 34, kl: 0.95, overlap pos: 0, overlap site: 0, time: 10.94 sec
# index: 35, kl: 1.138, overlap pos: 0, overlap site: 0, time: 10.843 sec
# index: 36, kl: 1.076, overlap pos: 0, overlap site: 0, time: 10.879 sec
# index: 37, kl: 1.13, overlap pos: 0, overlap site: 0, time: 10.922 sec
# index: 38, kl: 1.061, overlap pos: 0, overlap site: 0, time: 10.935 sec
# index: 39, kl: 1.12, overlap pos: 0, overlap site: 0, time: 10.939 sec
# index: 40, kl: 1.048, overlap pos: 0, overlap site: 0, time: 11.441 sec
# index: 41, kl: 0.995, overlap pos: 0, overlap site: 0, time: 11.682 sec
# index: 42, kl: 1.026, overlap pos: 0, overlap site: 0, time: 11.503 sec
# index: 43, kl: 1.064, overlap pos: 0, overlap site: 0, time: 11.484 sec
# index: 44, kl: 1.022, overlap pos: 0, overlap site: 1, time: 11.511 sec
# index: 45, kl: 1.044, overlap pos: 0, overlap site: 0, time: 11.408 sec
# index: 46, kl: 1.049, overlap pos: 0, overlap site: 1, time: 11.514 sec
# index: 47, kl: 0.919, overlap pos: 0, overlap site: 0, time: 11.335 sec
# index: 48, kl: 1.028, overlap pos: 0, overlap site: 0, time: 11.383 sec
# index: 49, kl: 1.032, overlap pos: 0, overlap site: 0, time: 11.402 sec
# index: 50, kl: 1.028, overlap pos: 0, overlap site: 0, time: 5.764 sec
# index: 51, kl: 1.07, overlap pos: 0, overlap site: 0, time: 5.715 sec
# index: 52, kl: 0.93, overlap pos: 0, overlap site: 0, time: 5.719 sec
# index: 53, kl: 1.008, overlap pos: 0, overlap site: 0, time: 5.801 sec
# index: 54, kl: 1.085, overlap pos: 0, overlap site: 0, time: 5.757 sec
# index: 55, kl: 0.985, overlap pos: 0, overlap site: 0, time: 5.747 sec
# index: 56, kl: 1.046, overlap pos: 0, overlap site: 0, time: 5.759 sec
# index: 57, kl: 1.069, overlap pos: 0, overlap site: 0, time: 5.742 sec
# index: 58, kl: 1.009, overlap pos: 0, overlap site: 0, time: 5.723 sec
# index: 59, kl: 1.041, overlap pos: 0, overlap site: 0, time: 5.676 sec
# index: 60, kl: 0.987, overlap pos: 0, overlap site: 0, time: 22.603 sec
# index: 61, kl: 1.108, overlap pos: 0, overlap site: 0, time: 22.091 sec
# index: 62, kl: 1.034, overlap pos: 0, overlap site: 0, time: 22.503 sec
# index: 63, kl: 1.027, overlap pos: 0, overlap site: 0, time: 22.024 sec
# index: 64, kl: 0.968, overlap pos: 0, overlap site: 0, time: 22.082 sec
# index: 65, kl: 1.046, overlap pos: 1, overlap site: 1, time: 22.083 sec
# index: 66, kl: 1.018, overlap pos: 0, overlap site: 0, time: 22.009 sec
# index: 67, kl: 1.007, overlap pos: 0, overlap site: 2, time: 22.296 sec
# index: 68, kl: 1.38, overlap pos: 0, overlap site: 0, time: 22.18 sec
# index: 69, kl: 1.049, overlap pos: 0, overlap site: 1, time: 22.252 sec
